# %%
import json
import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join
import os

# %%
data_path = '../data/DeckLists/'
deck_files = [f for f in listdir(data_path) if isfile(join(data_path, f)) and 'Identifier' not in f]

# %%
#dict -->  keys are the cards w/ a list 
#dataframe columns = deckname as str, card name as str, count as int, sideboard as bool
deck = {'deckname':[], 'cardname':[], 'card_count':[], 'sideboard':[]}


for file_name in deck_files:
    companion = 0
    file = open(data_path+file_name, 'r')
    sideboard = False
    for line in file:
        
        items = line.split(" ")
        if (items[0][:4] == 'Deck'):
            pass
        elif (items[0][:9] == 'Companion'):
            companion = 1
        elif '\n' in items or items[0][:9] == 'Sideboard':
            if companion == 1:
                companion -= 1
            else:
                sideboard = True
        else:
            try:
                deck['deckname'].append(file_name)
                deck['cardname'].append(" ".join(items[1:]).replace('\n',''))
                deck['card_count'].append(int(items[0]))
                deck['sideboard'].append(sideboard)
            except (Exception, ValueError) as error:
                 print(f'Unable to process: {error}')
                 print(file)
                

parsed_df = pd.DataFrame(deck)

# %%
parsed_df.info()
parsed_df.loc[parsed_df['sideboard'] == True, ['deckname', 'card_count']].groupby('deckname').sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1144 entries, 0 to 1143
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   deckname    1144 non-null   object
#  1   cardname    1144 non-null   object
#  2   card_count  1144 non-null   int64
#  3   sideboard   1144 non-null   bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 28.1+ KB
#                                                     card_count
# deckname
# Andrea-Mengucci-Mono-Red-Aggro-Magic-World-Cham...          15
# Autumn-Burchett-Temur-Reclamation-Magic-World-C...          15
# Chris-Kvartek-Temur-Reclamation-Magic-World-Cha...          15
# Eli-Loveman-Mono-Red-Aggro-Magic-World-Champion...          15
# Gabriel-Nassif-Jeskai-Fires-Magic-World-Champio...          15
# Javier-Dominguez-Jeskai-Fires-Magic-World-Champ...          15
# Jean-Emmanuel-Depraz-Temur-Reclamation-Magic-Wo...          15
# Matias-Leveratto-Temur-Reclamation-Magic-World-...          15
# Márcio-Carvalho-Jeskai-Fires-Magic-World-Champi...          15
# Ondřej-Stráský-Azorius-Control-Magic-World-Cham...          15
# Paulo-Vitor-Damo-da-Rosa-Azorius-Control-Magic-...          15
# Piotr-Głogowski-Jund-Sacrifice-Magic-World-Cham...          15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)               15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(1)            15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(10)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(11)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(12)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(13)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(14)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(15)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(16)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(17)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(18)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(19)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(2)            15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(20)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(21)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(22)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(23)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(24)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(25)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(26)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(27)           15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(3)            15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(4)            15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(5)            15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(6)            15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(7)            15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(8)            15
# Platinum-Mythic-Rank-Player-Traditional-(Bo3)(9)            15
# Raphaël-Lévy-Jeskai-Fires-Magic-World-Champions...          15
# Sebastián-Pozzo-Mono-Red-Aggro-Magic-World-Cham...          15
# Seth-Manfield-Mono-Red-Aggro-Magic-World-Champi...          15
# Thoralf-Severin-Azorius-Control-Magic-World-Cha...          15

# %%
import psycopg2 as psy
from psycopg2 import sql
from io import StringIO
import sqlalchemy
from sqlalchemy import create_engine

def connect(connection_details):  
    """accepts connection details, establishes connection and returns it"""
    conn = None
    try:
        print('Connecting to PostgreSQL database...')
        conn = psy.connect(**connection_details)
    except (Exception, psy.DatabaseError) as error:
        print(f'Unable to connect to the database: {error}')
        sys.exit(1)
    print('Connection successful')
    return conn

    
con_details = {"dbname" : 'pay_to_play', 
               "user" : os.environ['PGSQL_P_USER'], 
               "password" : os.environ['PGSQL_P_PWD'], 
               "host" : 'localhost'}    

conn = connect(con_details)
# Out:
# Connecting to PostgreSQL database...
# Connection successful

# %%
# def add_uuid(deck_df, conn, uuid_field, sql_lookup_field, df_lookup_field, table):
#     uuid = sql.Identifier(uuid_field)
#     query = sql.SQL("SELECT {fields} FROM {tbl}").format(
#         fields = sql.SQL(', ').join([sql.Identifier(uuid_field), sql.Identifier(sql_lookup_field)]),
#         tbl = sql.Identifier(table))
#     name_id_df = pd.read_sql(query, conn).groupby(sql_lookup_field).max()
#     return deck_df.merge(name_id_df, how = 'left', left_on=df_lookup_field, right_on=sql_lookup_field)
        
def get_most_recent_uuid_for_card_names(conn):
    query = sql.SQL("""
        WITH newestsetdate AS (
            SELECT name, MAX(setreleasedate) as max_date
            FROM core
            JOIN setdetails ON "setCode" = "setcode"
            GROUP BY name
            ),
            newestset AS (
            SELECT name, setcode
            FROM newestsetdate
            JOIN setdetails ON newestsetdate.max_date = setdetails.setreleasedate
            )

            SELECT core.uuid, newestset.name
            FROM core
            INNER JOIN newestset ON newestset.name = core.name AND newestset.setcode = core."setCode";""")
    return pd.read_sql(query, conn).groupby("name").max() 

def add_uuid_to_deck(deck_df, conn, df_name_field):
    name_id_df = get_most_recent_uuid_for_card_names(conn)
    return deck_df.merge(name_id_df, how = 'left', left_on=df_name_field, right_on="name")

# %%
uuid_deck = add_uuid_to_deck(parsed_df, conn, "cardname")

# %%
uuid_deck.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1144 entries, 0 to 1143
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   deckname    1144 non-null   object
#  1   cardname    1144 non-null   object
#  2   card_count  1144 non-null   int64
#  3   sideboard   1144 non-null   bool
#  4   uuid        1010 non-null   object
# dtypes: bool(1), int64(1), object(3)
# memory usage: 45.8+ KB

# %%
uuid_deck
# Out:
#                                               deckname  \
# 0     Platinum-Mythic-Rank-Player-Traditional-(Bo3)(7)
# 1     Platinum-Mythic-Rank-Player-Traditional-(Bo3)(7)
# 2     Platinum-Mythic-Rank-Player-Traditional-(Bo3)(7)
# 3     Platinum-Mythic-Rank-Player-Traditional-(Bo3)(7)
# 4     Platinum-Mythic-Rank-Player-Traditional-(Bo3)(7)
# ...                                                ...
# 1139  Platinum-Mythic-Rank-Player-Traditional-(Bo3)(4)
# 1140  Platinum-Mythic-Rank-Player-Traditional-(Bo3)(4)
# 1141  Platinum-Mythic-Rank-Player-Traditional-(Bo3)(4)
# 1142  Platinum-Mythic-Rank-Player-Traditional-(Bo3)(4)
# 1143  Platinum-Mythic-Rank-Player-Traditional-(Bo3)(4)
#
#                          cardname  card_count  sideboard  \
# 0             Thrashing Brontodon           2      False
# 1                 Trail of Crumbs           3      False
# 2                 Kazandu Mammoth           4      False
# 3     Vorinclex, Monstrous Raider           2      False
# 4                Lovestruck Beast           4      False
# ...                           ...         ...        ...
# 1139      Klothys, God of Destiny           2       True
# 1140   Vivien, Monsters' Advocate           2       True
# 1141             Mystical Dispute           3       True
# 1142                 Ox of Agonas           2       True
# 1143       Obosh, the Preypiercer           1       True
#
#                                       uuid
# 0     523c83b0-ee94-5f0a-9ad9-f7efb5aad95e
# 1     2e5c5bd2-ed4a-556f-a920-10ee0ddcb6cc
# 2                                      NaN
# 3     f85a6483-b319-54a8-ac93-3dfe883fd166
# 4                                      NaN
# ...                                    ...
# 1139  bed702eb-e2ed-5989-9341-3b1198980180
# 1140  5e52bd2a-f453-58d1-ab8a-9d42295f445e
# 1141  5651bd95-cb41-5266-8654-93707f0c4f9a
# 1142  82cd6def-fef5-5e08-8af8-934f1be45237
# 1143  310e4b40-8931-5d39-8e63-399d913e7285
#
# [1144 rows x 5 columns]

# %%
def add_new_card_data(conn_details, card_inf_df, table, conn):
    engine_path = "postgresql+psycopg2://" + conn_details['user'] + ":" + conn_details['password']  
    engine_path +='@localhost:5432/' +conn_details['dbname']
    engine = create_engine(engine_path)
    try:
        card_inf_df.to_sql(table, engine, index=False, if_exists='append')
    except (Exception, psy.DatabaseError) as error:
        print(f'Error: {error}')
        conn.rollback()
        return 1
    conn.commit()
    print(f'Successful updating of {table}')

# %%
missing_uuids = uuid_deck[uuid_deck['uuid'] != uuid_deck['uuid']].drop('uuid', axis=1)
missing_uuids.head()
deck_load = uuid_deck[uuid_deck['uuid'] == uuid_deck['uuid']].drop('cardname', axis = 1)
deck_load.head()
# Out:
#                                            deckname  card_count  sideboard  \
# 0  Platinum-Mythic-Rank-Player-Traditional-(Bo3)(7)           2      False
# 1  Platinum-Mythic-Rank-Player-Traditional-(Bo3)(7)           3      False
# 3  Platinum-Mythic-Rank-Player-Traditional-(Bo3)(7)           2      False
# 5  Platinum-Mythic-Rank-Player-Traditional-(Bo3)(7)           4      False
# 6  Platinum-Mythic-Rank-Player-Traditional-(Bo3)(7)           4      False
#
#                                    uuid
# 0  523c83b0-ee94-5f0a-9ad9-f7efb5aad95e
# 1  2e5c5bd2-ed4a-556f-a920-10ee0ddcb6cc
# 3  f85a6483-b319-54a8-ac93-3dfe883fd166
# 5  a12d890a-1619-5545-b2f0-3897d6c61c8b
# 6  3ef6edae-e899-521c-a731-3aeeff8b154e

# %%
add_new_card_data(con_details, deck_load , 'decklists', conn)
# Out:
# Successful updating of decklists

# %%
add_new_card_data(con_details, missing_uuids, 'nan_uuid_decklists', conn)
# Out:
# Successful updating of nan_uuid_decklists

# %%
# 45 unmatched.  373 matched.  Need to now build a multi-field text-scan/match for name to address these.
query = sql.SQL("""
    SELECT cardname
    FROM nan_uuid_decklists
    GROUP BY cardname""")
unmatched_df = pd.read_sql(query, conn)

# %%
from string import punctuation

def text_rawify(text):
    lowered = text.lower()
    punct_less = ''.join([c for c in lowered if c not in punctuation])
    raw_text = ''.join(punct_less.split(' '))
    return raw_text

# %%
unmatched_df['raw_name'] = unmatched_df['cardname'].apply(text_rawify)

# %%
#unmatched_df.drop('rawtext', axis=1, inplace=True)
unmatched_df.head()
# Out:
#               cardname            raw_name
# 0    Pelakka Predation    pelakkapredation
# 1  Barkchannel Pathway  barkchannelpathway
# 2  Brightclimb Pathway  brightclimbpathway
# 3   Egon, God of Death      egongodofdeath
# 4     Darkbore Pathway     darkborepathway

# %%
unmatched_df.loc[unmatched_df['raw_name'] == 'expansionexplosion224grn','raw_name'] = 'expansionexplosion'

# %%
#Expansion // Explosion 224 (GRN) just needs some manual processing as the decklist had wonky data w/ the '224 (GRN)
# additionally, it seems upon limited manual research, many of these cards are double-faced and the face names appear combined in name field.
# will try to do a deck-list card name rawtext search in master card name rawtext to match. 

name_id_df = get_most_recent_uuid_for_card_names(conn).reset_index()
name_id_df['rawname'] = name_id_df['name'].apply(text_rawify)
name_id_df.head()
# Out:
#                     name                                  uuid  \
# 0                 Absorb  7d6637d8-1d04-5977-a925-f4187ac3fd1c
# 1        Absorb Identity  fa3e1540-8f7c-5fcc-9aaf-19b6b4af1c6b
# 2    Acclaimed Contender  7ebde572-911a-5ce4-a607-fe21718e01e0
# 3  Acolyte of Affliction  3a61e0b3-4c1a-5971-a27d-81ee96d85b4a
# 4    Acquisitions Expert  16b73777-ebad-5771-b1c7-0726eeda9f3c
#
#                rawname
# 0               absorb
# 1       absorbidentity
# 2   acclaimedcontender
# 3  acolyteofaffliction
# 4   acquisitionsexpert

# %%
def find_unmatched_uuids(cardname, unmatched_rawname, core_card_names_df, search_in_col, uuid_col_num):
    result = core_card_names_df[core_card_names_df[search_in_col].str.contains(unmatched_rawname, na=False, regex=False) == True]
    if result.empty == False:
        return cardname, unmatched_rawname, result.iloc[0,uuid_col_num]

# %%
uuid_matches = []
for i in range(unmatched_df.shape[0]):
    match = find_unmatched_uuids(unmatched_df.iloc[i,0],unmatched_df.iloc[i,1], name_id_df, 'rawname',1)
    if match is not None:
        uuid_matches.append(match)

matched_name = pd.DataFrame(uuid_matches, columns=['cardname', 'rawname', 'uuid'])

# %%
matched_name
# Out:
#                              cardname                 rawname  \
# 0                   Pelakka Predation        pelakkapredation
# 1                 Barkchannel Pathway      barkchannelpathway
# 2                 Brightclimb Pathway      brightclimbpathway
# 3                  Egon, God of Death          egongodofdeath
# 4                    Darkbore Pathway         darkborepathway
# 5                     Beanstalk Giant          beanstalkgiant
# 6                Turntimber Symbiosis     turntimbersymbiosis
# 7                  Blightstep Pathway       blightsteppathway
# 8                  Branchloft Pathway       branchloftpathway
# 9          Reidane, God of the Worthy   reidanegodoftheworthy
# 10         Birgi, God of Storytelling  birgigodofstorytelling
# 11                Needleverge Pathway      needlevergepathway
# 12                    Foulmire Knight          foulmireknight
# 13                  Bonecrusher Giant        bonecrushergiant
# 14                      Hagra Mauling            hagramauling
# 15                 Valki, God of Lies          valkigodoflies
# 16                  Spikefield Hazard        spikefieldhazard
# 17                 Faerie Guidemother       faerieguidemother
# 18  Expansion // Explosion  224 (GRN)      expansionexplosion
# 19                     Sejiri Shelter           sejirishelter
# 20              Shepherd of the Flock      shepherdoftheflock
# 21                    Kazandu Mammoth          kazandumammoth
# 22                     Ondu Inversion           onduinversion
# 23                    Malakir Rebirth          malakirrebirth
# 24                 Clearwater Pathway       clearwaterpathway
# 25                  Bala Ged Recovery         balagedrecovery
# 26                Tangled Florahedron      tangledflorahedron
# 27                     Rimrock Knight           rimrockknight
# 28                  Hengegate Pathway        hengegatepathway
# 29             Embereth Shieldbreaker   emberethshieldbreaker
# 30                Agadeem's Awakening       agadeemsawakening
# 31                 Riverglide Pathway       riverglidepathway
# 32                  Cragcrown Pathway        cragcrownpathway
# 33                    Brazen Borrower          brazenborrower
# 34                      Emeria's Call             emeriascall
# 35                       Giant Killer             giantkiller
# 36                   Lovestruck Beast         lovestruckbeast
# 37             Tergrid, God of Fright      tergridgodoffright
# 38          Cosima, God of the Voyage    cosimagodofthevoyage
# 39                    Glasspool Mimic          glasspoolmimic
# 40              Shatterskull Smashing    shatterskullsmashing
# 41                    Kabira Takedown          kabiratakedown
# 42                    Murderous Rider          murderousrider
# 43             Esika, God of the Tree       esikagodofthetree
# 44              Halvar, God of Battle       halvargodofbattle
#
#                                     uuid
# 0   956cb1d0-2beb-51f9-8f33-38cb28280d2b
# 1   c277aee9-4263-5fbe-ad24-57f5533f14da
# 2   7e47679e-24a0-57dc-970f-b29efb7d55ec
# 3   e7619d66-eed8-5e0d-9b45-26e299de2ac1
# 4   8dbc37a4-d21a-5539-8e45-ef2955a0456d
# 5   e78d0b7a-7b47-59b2-a148-c5a130224adb
# 6   f6aeb170-0112-5224-8df5-274ce7558327
# 7   f77952ce-3925-5753-b2b1-45b332ab893d
# 8   6072997d-fb42-5bc9-b7ee-b82f00165c4d
# 9   fb2bf34b-1c20-5fc2-97f1-5d5170a94364
# 10  af16a633-1a07-5752-8bb4-503c859c8e5c
# 11  c4f04cbb-7139-5e80-9d6b-3e29ac3cde84
# 12  c7c388bc-8daf-5b5f-b91d-302865b49d4a
# 13  d26fdb0c-80d4-5ea2-af6e-adbd290fc163
# 14  ee07b2ff-7520-5e0f-952d-675a7ec95965
# 15  cd94f98e-85bb-5eea-b1c1-5d5b39e2e9e1
# 16  d0566eb7-d5b9-57d5-80be-195dbd71595c
# 17  9e5550cb-10e1-59ca-b5c7-435c3dc263fd
# 18  f2f6904a-e7f7-524c-9077-feab5f2e4577
# 19  c1b2f597-ae58-5fac-93af-e1e95af87e68
# 20  edf8f64f-384d-5ad1-a720-f3649ed57e3c
# 21  d8b73b4b-41a3-5b69-91cb-9d52225b5bef
# 22  df15adcf-2c3a-559b-a40d-b135b7a1ebd5
# 23  08438b77-41e3-5bdf-bbe4-5c76a95f04d5
# 24  f31fdd39-6824-5bf5-b6a1-f8333aeae539
# 25  5fc410b3-69aa-5409-aad0-bfa838811d7f
# 26  9b9ee2cb-4f20-573a-86d4-fe43209a310f
# 27  cc319b2b-9191-5b58-8749-6d008be25878
# 28  d34646f9-c799-5b3c-9ef8-eab6776a6d97
# 29  f668c83c-f302-5d4e-87ad-c0e12cf6e110
# 30  d5ea3ded-5799-5625-8a3c-bad72e6aeb39
# 31  e3a27a1c-52cb-5e6c-9dad-464d23d7c307
# 32  dc222dc4-d430-5485-8b44-fd75d8608aa8
# 33  f21cc3ef-1bd5-55b6-a5dd-11bdf3713a54
# 34  dde525a3-231d-58c4-a49d-4d6b6d811f19
# 35  fb77bdb3-9f6d-5e6e-95ec-e10bc9465ffc
# 36  89fd5608-1ece-5c6f-8428-828d599b9cad
# 37  ebba06ad-eae1-5a32-9fe6-ebc7d3eeeec1
# 38  ac4ffd71-aa91-5694-8a0d-b0e303ca5385
# 39  992af866-53ec-5530-bd0a-bd94d4be939e
# 40  bb2109b7-8ecf-558e-829f-cc2b455634ab
# 41  c3f3ff5b-5c29-5b6c-a794-69efe192f2d5
# 42  cde8ada5-6815-5946-ae7a-8607a9da00a1
# 43  b8e15f58-1152-5c18-ae93-70ae50f71024
# 44  c87e91b0-9117-538e-800f-f8c915aaea8a

# %%
query = sql.SQL("""
    SELECT *
    FROM nan_uuid_decklists
    """)
nan_uuid_decklists = pd.read_sql(query, conn)
to_update = nan_uuid_decklists.merge(matched_name, how = 'left', left_on='cardname', right_on='cardname')
to_update.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134 entries, 0 to 133
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   cardname    134 non-null    object
#  1   card_count  134 non-null    int64
#  2   sideboard   134 non-null    bool
#  3   deckname    134 non-null    object
#  4   rawname     134 non-null    object
#  5   uuid        134 non-null    object
# dtypes: bool(1), int64(1), object(4)
# memory usage: 6.4+ KB

# %%
add_new_card_data(con_details, to_update[['deckname', 'card_count', 'sideboard', 'uuid']], 'decklists', conn)
# Out:
# Successful updating of decklists

# %%
#woo hoo!!!!! it worked!
